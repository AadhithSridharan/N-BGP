# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\Aadhith\\Desktop\\N-BGP\\NBGP-radii.csv")
df
# Out:
#     Label  OuterWidth  OuterHeight  InnerWidth  InnerHeight  WidthRatio  \
# 0      A+    0.373861     0.350801    0.233559     0.247313    1.600716
# 1      O+    0.289181     0.251868    0.190018     0.174537    1.521865
# 2      O+    0.270783     0.274929    0.172028     0.179911    1.574059
# 3      A+    0.312028     0.280961    0.191744     0.180480    1.627320
# 4     AB+    0.346726     0.267171    0.211993     0.179929    1.635555
# ..    ...         ...          ...         ...          ...         ...
# 96     B+    0.434786     0.348203    0.280498     0.245320    1.550051
# 97     A+    0.368096     0.302011    0.226797     0.201174    1.623019
# 98     B+    0.329377     0.324537    0.207295     0.220356    1.588927
# 99     B+    0.323754     0.280569    0.205569     0.191779    1.574916
# 100    O+    0.314502     0.264128    0.200658     0.170569    1.567349
#
#      HeightRatio
# 0       1.418447
# 1       1.443062
# 2       1.528138
# 3       1.556739
# ...

# %% [markdown]
# # EDA:

# %%
df.columns
# Out:
# Index(['Label', 'OuterWidth', 'OuterHeight', 'InnerWidth', 'InnerHeight',
#        'WidthRatio', 'HeightRatio'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Label  OuterWidth  OuterHeight  InnerWidth  InnerHeight  WidthRatio  \
# 0      A+    0.373861     0.350801    0.233559     0.247313    1.600716
# 1      O+    0.289181     0.251868    0.190018     0.174537    1.521865
# 2      O+    0.270783     0.274929    0.172028     0.179911    1.574059
# 3      A+    0.312028     0.280961    0.191744     0.180480    1.627320
# 4     AB+    0.346726     0.267171    0.211993     0.179929    1.635555
# ..    ...         ...          ...         ...          ...         ...
# 96     B+    0.434786     0.348203    0.280498     0.245320    1.550051
# 97     A+    0.368096     0.302011    0.226797     0.201174    1.623019
# 98     B+    0.329377     0.324537    0.207295     0.220356    1.588927
# 99     B+    0.323754     0.280569    0.205569     0.191779    1.574916
# 100    O+    0.314502     0.264128    0.200658     0.170569    1.567349
#
#      HeightRatio
# 0       1.418447
# 1       1.443062
# ...

# %%
print("\nPairplot of numerical features:")
sns.pairplot(df, hue='Label')
plt.show()
# Out:
# Pairplot of numerical features:

# %%
label_counts = df['Label'].value_counts()

plt.figure(figsize=(4, 4))
plt.pie(label_counts, labels=label_counts.index)
plt.title('Pie Chart of distribution of blood groups in dataset')

plt.show()

# %% [markdown]
# # Preprocessing:

# %%
X = df[['OuterWidth', 'OuterHeight', 'InnerWidth', 'InnerHeight','WidthRatio', 'HeightRatio']]
y = df["Label"]

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
X = ss.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X,y,test_size=0.2,shuffle=True)

# %% [markdown]
# # Model:

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_val)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred, y_val)
# Out:
# 0.47619047619047616
